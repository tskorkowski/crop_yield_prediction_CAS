# %%
# Setup
# !pip install --quiet --upgrade pip

# Install the dependencies.
# !pip install --quiet -r requirements.txt

# Restart the runtime by ending the process.
exit()
# Out:
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [86 lines of output]
#       Using numpy 2.1.2
#       running egg_info
#       writing gdal-utils/GDAL.egg-info/PKG-INFO
#       writing dependency_links to gdal-utils/GDAL.egg-info/dependency_links.txt
#       writing entry points to gdal-utils/GDAL.egg-info/entry_points.txt
#       writing requirements to gdal-utils/GDAL.egg-info/requires.txt
#       writing top-level names to gdal-utils/GDAL.egg-info/top_level.txt
#       Traceback (most recent call last):
#         File "<string>", line 91, in fetch_config
#         File "/opt/conda/lib/python3.10/subprocess.py", line 971, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/opt/conda/lib/python3.10/subprocess.py", line 1863, in _execute_child
#           raise child_exception_type(errno_num, err_msg, err_filename)
#       FileNotFoundError: [Errno 2] No such file or directory: 'gdal-config'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 231, in get_gdal_config
#         File "<string>", line 94, in fetch_config
#       __main__.gdal_config_error: [Errno 2] No such file or directory: 'gdal-config'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/opt/conda/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/opt/conda/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/opt/conda/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 332, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 302, in _get_build_requires
#           self.run_setup()
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 318, in run_setup
#           exec(code, locals())
#         File "<string>", line 421, in <module>
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/__init__.py", line 117, in setup
#           return distutils.core.setup(**attrs)
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 183, in setup
#           return run_commands(dist)
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 199, in run_commands
#           dist.run_commands()
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 954, in run_commands
#           self.run_command(cmd)
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 950, in run_command
#           super().run_command(command)
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 973, in run_command
#           cmd_obj.run()
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 311, in run
#           self.find_sources()
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 319, in find_sources
#           mm.run()
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 540, in run
#           self.add_defaults()
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 578, in add_defaults
#           sdist.add_defaults(self)
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/command/sdist.py", line 108, in add_defaults
#           super().add_defaults()
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/_distutils/command/sdist.py", line 238, in add_defaults
#           self._add_defaults_ext()
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/_distutils/command/sdist.py", line 322, in _add_defaults_ext
#           build_ext = self.get_finalized_command('build_ext')
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 303, in get_finalized_command
#           cmd_obj.ensure_finalized()
#         File "/var/tmp/pip-build-env-vpu6_3f7/overlay/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 111, in ensure_finalized
#           self.finalize_options()
#         File "<string>", line 307, in finalize_options
#         File "<string>", line 237, in get_gdal_config
#       __main__.gdal_config_error: Traceback (most recent call last):
#         File "<string>", line 91, in fetch_config
#         File "/opt/conda/lib/python3.10/subprocess.py", line 971, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/opt/conda/lib/python3.10/subprocess.py", line 1863, in _execute_child
#           raise child_exception_type(errno_num, err_msg, err_filename)
#       FileNotFoundError: [Errno 2] No such file or directory: 'gdal-config'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 231, in get_gdal_config
#         File "<string>", line 94, in fetch_config
#       gdal_config_error: [Errno 2] No such file or directory: 'gdal-config'
#
#       Could not find gdal-config. Make sure you have installed the GDAL native library and development headers.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !apt-get install gdal-bin
# !pip install leafmap[raster]
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# Collecting leafmap[raster]
#   Downloading leafmap-0.38.3-py2.py3-none-any.whl.metadata (16 kB)
# Collecting anywidget>=0.9.13 (from leafmap[raster])
#   Downloading anywidget-0.9.13-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: bqplot>=0.12.43 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (0.12.43)
# Requirement already satisfied: colour>=0.1.5 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (0.1.5)
# Requirement already satisfied: folium>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (0.16.0)
# Collecting gdown>=5.1.0 (from leafmap[raster])
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting geojson>=3.1.0 (from leafmap[raster])
#   Downloading geojson-3.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.18.2 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (0.19.2)
# Collecting ipyvuetify>=1.9.4 (from leafmap[raster])
#   Downloading ipyvuetify-1.10.0-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets>=7.6.0 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (8.1.5)
# Requirement already satisfied: matplotlib>=3.7.1 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (3.9.2)
# Collecting numpy<3.0.0,>=1.25.0 (from leafmap[raster])
#   Using cached numpy-2.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: pandas>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (2.2.3)
# Requirement already satisfied: plotly>=5.15.0 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (5.15.0)
# Collecting psutil>=5.9.5 (from leafmap[raster])
#   Downloading psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: pyshp>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (2.3.1)
# Collecting pystac-client>=0.8.2 (from leafmap[raster])
#   Downloading pystac_client-0.8.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: python-box>=7.2.0 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (7.2.0)
# Requirement already satisfied: scooby>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (0.10.0)
# Requirement already satisfied: setuptools>=71.0.4 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (73.0.1)
# Collecting whiteboxgui>=2.3.0 (from leafmap[raster])
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xyzservices>=2024.6.0 in /opt/conda/lib/python3.10/site-packages (from leafmap[raster]) (2024.9.0)
# Collecting duckdb>=0.10.3 (from leafmap[raster])
#   Downloading duckdb-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (762 bytes)
# Collecting localtileserver>=0.10.0 (from leafmap[raster])
#   Downloading localtileserver-0.10.4-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-server-proxy (from leafmap[raster])
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting rio-cogeo (from leafmap[raster])
#   Downloading rio_cogeo-5.3.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting rioxarray (from leafmap[raster])
#   Downloading rioxarray-0.17.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting netcdf4 (from leafmap[raster])
#   Downloading netCDF4-1.7.1.post2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting pynhd (from leafmap[raster])
#   Downloading pynhd-0.18.0-py3-none-any.whl.metadata (25 kB)
# Collecting py3dep (from leafmap[raster])
#   Downloading py3dep-0.18.0-py3-none-any.whl.metadata (20 kB)
# Collecting d2spy (from leafmap[raster])
#   Downloading d2spy-0.1.11-py3-none-any.whl.metadata (1.6 kB)
# Collecting psygnal>=0.8.1 (from anywidget>=0.9.13->leafmap[raster])
#   Downloading psygnal-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from anywidget>=0.9.13->leafmap[raster]) (4.12.2)
# Requirement already satisfied: traitlets>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from bqplot>=0.12.43->leafmap[raster]) (5.14.3)
# Requirement already satisfied: traittypes>=0.0.6 in /opt/conda/lib/python3.10/site-packages (from bqplot>=0.12.43->leafmap[raster]) (0.2.1)
# Requirement already satisfied: branca>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from folium>=0.14.0->leafmap[raster]) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.10/site-packages (from folium>=0.14.0->leafmap[raster]) (3.1.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from folium>=0.14.0->leafmap[raster]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown>=5.1.0->leafmap[raster]) (4.12.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown>=5.1.0->leafmap[raster]) (3.16.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown>=5.1.0->leafmap[raster]) (4.66.5)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from ipyleaflet>=0.18.2->leafmap[raster]) (0.19.2)
# Collecting ipyvue<2,>=1.7 (from ipyvuetify>=1.9.4->leafmap[raster])
#   Downloading ipyvue-1.11.1-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.0->leafmap[raster]) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.0->leafmap[raster]) (8.21.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.0->leafmap[raster]) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.0->leafmap[raster]) (3.0.13)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from localtileserver>=0.10.0->leafmap[raster]) (8.1.7)
# Collecting flask<4,>=2.0.0 (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Flask-Caching (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading Flask_Caching-2.3.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting flask-restx>=1.3.0 (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading rio_tiler-6.7.0-py3-none-any.whl.metadata (11 kB)
# Collecting server-thread (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading server_thread-0.2.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: werkzeug in /opt/conda/lib/python3.10/site-packages (from localtileserver>=0.10.0->leafmap[raster]) (3.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.1->leafmap[raster]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.1->leafmap[raster]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.1->leafmap[raster]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.1->leafmap[raster]) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.1->leafmap[raster]) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.1->leafmap[raster]) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.1->leafmap[raster]) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.1->leafmap[raster]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.0.3->leafmap[raster]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.0.3->leafmap[raster]) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly>=5.15.0->leafmap[raster]) (9.0.0)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client>=0.8.2->leafmap[raster])
#   Downloading pystac-1.11.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: ipytree in /opt/conda/lib/python3.10/site-packages (from whiteboxgui>=2.3.0->leafmap[raster]) (0.2.2)
# Collecting whitebox (from whiteboxgui>=2.3.0->leafmap[raster])
#   Downloading whitebox-2.3.5-py2.py3-none-any.whl.metadata (10 kB)
# Collecting geojson-pydantic<2.0.0,>=1.1.1 (from d2spy->leafmap[raster])
#   Downloading geojson_pydantic-1.1.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: geopandas<2.0.0,>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from d2spy->leafmap[raster]) (1.0.1)
# Collecting rasterio<2.0.0,>=1.3.11 (from d2spy->leafmap[raster])
#   Downloading rasterio-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from jupyter-server-proxy->leafmap[raster]) (3.10.5)
# Requirement already satisfied: jupyter-server>=1.24.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server-proxy->leafmap[raster]) (1.24.0)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->leafmap[raster])
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tornado>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server-proxy->leafmap[raster]) (6.4.1)
# Collecting cftime (from netcdf4->leafmap[raster])
#   Downloading cftime-1.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from netcdf4->leafmap[raster]) (2024.8.30)
# Collecting async-retriever<0.19,>=0.18 (from py3dep->leafmap[raster])
#   Downloading async_retriever-0.18.0-py3-none-any.whl.metadata (16 kB)
# Collecting cytoolz (from py3dep->leafmap[raster])
#   Downloading cytoolz-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting pygeoogc<0.19,>=0.18 (from py3dep->leafmap[raster])
#   Downloading pygeoogc-0.18.0-py3-none-any.whl.metadata (18 kB)
# Collecting pygeoutils<0.19,>=0.18 (from py3dep->leafmap[raster])
#   Downloading pygeoutils-0.18.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from py3dep->leafmap[raster]) (1.13.1)
# Requirement already satisfied: shapely>=2 in /opt/conda/lib/python3.10/site-packages (from py3dep->leafmap[raster]) (2.0.6)
# Collecting xarray>=2023.1 (from py3dep->leafmap[raster])
#   Downloading xarray-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyproj>=3.3 in /opt/conda/lib/python3.10/site-packages (from rioxarray->leafmap[raster]) (3.6.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from pynhd->leafmap[raster]) (3.3)
# Requirement already satisfied: pyarrow>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from pynhd->leafmap[raster]) (9.0.0)
# Collecting morecantile<6.0,>=5.0 (from rio-cogeo->leafmap[raster])
#   Downloading morecantile-5.4.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: pydantic~=2.0 in /opt/conda/lib/python3.10/site-packages (from rio-cogeo->leafmap[raster]) (2.9.2)
# Collecting aiohttp-client-cache>=0.12.3 (from async-retriever<0.19,>=0.18->py3dep->leafmap[raster])
#   Downloading aiohttp_client_cache-0.12.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting aiosqlite (from async-retriever<0.19,>=0.18->py3dep->leafmap[raster])
#   Downloading aiosqlite-0.20.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from async-retriever<0.19,>=0.18->py3dep->leafmap[raster]) (1.6.0)
# Collecting ujson (from async-retriever<0.19,>=0.18->py3dep->leafmap[raster])
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (4.0.3)
# Collecting itsdangerous>=2.1.2 (from flask<4,>=2.0.0->localtileserver>=0.10.0->leafmap[raster])
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.6.2 (from flask<4,>=2.0.0->localtileserver>=0.10.0->leafmap[raster])
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver>=0.10.0->leafmap[raster])
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from flask-restx>=1.3.0->localtileserver>=0.10.0->leafmap[raster]) (4.23.0)
# Collecting importlib-resources (from flask-restx>=1.3.0->localtileserver>=0.10.0->leafmap[raster])
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/lib/python3.10/site-packages (from geopandas<2.0.0,>=1.0.1->d2spy->leafmap[raster]) (0.9.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (0.6.3)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=2.9->folium>=0.14.0->leafmap[raster]) (2.1.5)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (3.7.1)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (23.1.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (5.7.2)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (7.16.4)
# Requirement already satisfied: nbformat>=5.2.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (5.10.4)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.21.0)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (26.2.0)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.18.1)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic~=2.0->rio-cogeo->leafmap[raster]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic~=2.0->rio-cogeo->leafmap[raster]) (2.23.4)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from pygeoogc<0.19,>=0.18->py3dep->leafmap[raster]) (0.7.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from pygeoogc<0.19,>=0.18->py3dep->leafmap[raster]) (1.4.2)
# Collecting owslib>=0.27.2 (from pygeoogc<0.19,>=0.18->py3dep->leafmap[raster])
#   Downloading OWSLib-0.31.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting requests-cache>=0.9.6 (from pygeoogc<0.19,>=0.18->py3dep->leafmap[raster])
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting url-normalize>=1.4 (from pygeoogc<0.19,>=0.18->py3dep->leafmap[raster])
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.10/site-packages (from pygeoogc<0.19,>=0.18->py3dep->leafmap[raster]) (1.26.20)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.7.1->leafmap[raster]) (1.16.0)
# Collecting affine (from rasterio<2.0.0,>=1.3.11->d2spy->leafmap[raster])
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting cligj>=0.5 (from rasterio<2.0.0,>=1.3.11->d2spy->leafmap[raster])
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio<2.0.0,>=1.3.11->d2spy->leafmap[raster])
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->folium>=0.14.0->leafmap[raster]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->folium>=0.14.0->leafmap[raster]) (3.8)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown>=5.1.0->leafmap[raster]) (2.6)
# Requirement already satisfied: toolz>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from cytoolz->py3dep->leafmap[raster]) (0.12.1)
# Collecting cachelib<0.10.0,>=0.9.0 (from Flask-Caching->localtileserver>=0.10.0->leafmap[raster])
#   Downloading cachelib-0.9.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown>=5.1.0->leafmap[raster]) (1.7.1)
# Requirement already satisfied: cachetools in /opt/conda/lib/python3.10/site-packages (from rio-tiler->localtileserver>=0.10.0->leafmap[raster]) (4.2.4)
# Collecting color-operations (from rio-tiler->localtileserver>=0.10.0->leafmap[raster])
#   Downloading color_operations-0.1.6-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Collecting httpx (from rio-tiler->localtileserver>=0.10.0->leafmap[raster])
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting numexpr (from rio-tiler->localtileserver>=0.10.0->leafmap[raster])
#   Downloading numexpr-2.10.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: uvicorn in /opt/conda/lib/python3.10/site-packages (from server-thread->localtileserver>=0.10.0->leafmap[raster]) (0.30.6)
# Requirement already satisfied: Brotli in /opt/conda/lib/python3.10/site-packages (from aiohttp[speedups]>=3.8.3->async-retriever<0.19,>=0.18->py3dep->leafmap[raster]) (1.1.0)
# Collecting aiodns>=3.2.0 (from aiohttp[speedups]>=3.8.3->async-retriever<0.19,>=0.18->py3dep->leafmap[raster])
#   Downloading aiodns-3.2.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver>=0.10.0->leafmap[raster]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver>=0.10.0->leafmap[raster]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver>=0.10.0->leafmap[raster]) (0.20.0)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (4.2.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (6.1.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.5.1)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.2.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.20.0)
# Collecting lxml (from owslib>=0.27.2->pygeoogc<0.19,>=0.18->py3dep->leafmap[raster])
#   Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from owslib>=0.27.2->pygeoogc<0.19,>=0.18->py3dep->leafmap[raster]) (6.0.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (0.2.13)
# Collecting cattrs>=22.2 (from requests-cache>=0.9.6->pygeoogc<0.19,>=0.18->py3dep->leafmap[raster])
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (21.2.0)
# Collecting httpcore==1.* (from httpx->rio-tiler->localtileserver>=0.10.0->leafmap[raster])
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx->rio-tiler->localtileserver>=0.10.0->leafmap[raster]) (0.14.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap[raster]) (0.2.3)
# Collecting pycares>=4.0.0 (from aiodns>=3.2.0->aiohttp[speedups]>=3.8.3->async-retriever<0.19,>=0.18->py3dep->leafmap[raster])
#   Downloading pycares-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.17.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.22)
# Downloading anywidget-0.9.13-py3-none-any.whl (213 kB)
# Downloading duckdb-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 165.4 MB/s eta 0:00:00
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading geojson-3.1.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.10.0-py2.py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 123.4 MB/s eta 0:00:00
# Downloading localtileserver-0.10.4-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 111.8 MB/s eta 0:00:00
# Using cached numpy-2.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
# Downloading psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (290 kB)
# Downloading pystac_client-0.8.3-py3-none-any.whl (33 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
# Downloading d2spy-0.1.11-py3-none-any.whl (29 kB)
# Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl (37 kB)
# Downloading leafmap-0.38.3-py2.py3-none-any.whl (488 kB)
# Downloading netCDF4-1.7.1.post2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 157.6 MB/s eta 0:00:00
# Downloading py3dep-0.18.0-py3-none-any.whl (24 kB)
# Downloading rioxarray-0.17.0-py3-none-any.whl (61 kB)
# Downloading pynhd-0.18.0-py3-none-any.whl (50 kB)
# Downloading rio_cogeo-5.3.6-py3-none-any.whl (20 kB)
# Downloading async_retriever-0.18.0-py3-none-any.whl (16 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 171.5 MB/s eta 0:00:00
# Downloading geojson_pydantic-1.1.1-py3-none-any.whl (8.7 kB)
# Downloading ipyvue-1.11.1-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 126.1 MB/s eta 0:00:00
# Downloading morecantile-5.4.2-py3-none-any.whl (49 kB)
# Downloading psygnal-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (727 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.4/727.4 kB 39.6 MB/s eta 0:00:00
# Downloading pygeoogc-0.18.0-py3-none-any.whl (35 kB)
# Downloading pygeoutils-0.18.0-py3-none-any.whl (29 kB)
# Downloading pystac-1.11.0-py3-none-any.whl (183 kB)
# Downloading rasterio-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 150.2 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading xarray-2024.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 111.4 MB/s eta 0:00:00
# Downloading cftime-1.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 118.3 MB/s eta 0:00:00
# Downloading cytoolz-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 147.0 MB/s eta 0:00:00
# Downloading Flask_Caching-2.3.0-py3-none-any.whl (28 kB)
# Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Downloading rio_tiler-6.7.0-py3-none-any.whl (263 kB)
# Downloading server_thread-0.2.0-py3-none-any.whl (8.5 kB)
# Downloading whitebox-2.3.5-py2.py3-none-any.whl (72 kB)
# Downloading aiohttp_client_cache-0.12.3-py3-none-any.whl (32 kB)
# Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading OWSLib-0.31.0-py2.py3-none-any.whl (233 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading color_operations-0.1.6-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (186 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading numexpr-2.10.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (405 kB)
# Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
# Downloading aiodns-3.2.0-py3-none-any.whl (5.7 kB)
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
# Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 145.9 MB/s eta 0:00:00
# Downloading pycares-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
# Installing collected packages: aniso8601, whitebox, url-normalize, ujson, simpervisor, psygnal, psutil, numpy, lxml, itsdangerous, importlib-resources, httpcore, geojson, duckdb, cytoolz, cligj, click-plugins, cattrs, cachelib, blinker, aiosqlite, affine, server-thread, requests-cache, rasterio, pystac, pycares, owslib, numexpr, httpx, flask, color-operations, cftime, xarray, netcdf4, morecantile, geojson-pydantic, gdown, flask-cors, Flask-Caching, aiodns, rioxarray, rio-tiler, rio-cogeo, flask-restx, d2spy, aiohttp-client-cache, pystac-client, pygeoutils, localtileserver, ipyvue, async-retriever, anywidget, whiteboxgui, pygeoogc, ipyvuetify, pynhd, py3dep, leafmap, jupyter-server-proxy
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.3
#     Uninstalling psutil-5.9.3:
#       Successfully uninstalled psutil-5.9.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 2.1.2 which is incompatible.
# ibis-framework 8.0.0 requires numpy<2,>=1, but you have numpy 2.1.2 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.2 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 2.1.2 which is incompatible.
# Successfully installed Flask-Caching-2.3.0 affine-2.4.0 aiodns-3.2.0 aiohttp-client-cache-0.12.3 aiosqlite-0.20.0 aniso8601-9.0.1 anywidget-0.9.13 async-retriever-0.18.0 blinker-1.8.2 cachelib-0.9.0 cattrs-24.1.2 cftime-1.6.4 click-plugins-1.1.1 cligj-0.7.2 color-operations-0.1.6 cytoolz-1.0.0 d2spy-0.1.11 duckdb-1.1.1 flask-3.0.3 flask-cors-5.0.0 flask-restx-1.3.0 gdown-5.2.0 geojson-3.1.0 geojson-pydantic-1.1.1 httpcore-1.0.6 httpx-0.27.2 importlib-resources-6.4.5 ipyvue-1.11.1 ipyvuetify-1.10.0 itsdangerous-2.2.0 jupyter-server-proxy-4.4.0 leafmap-0.38.3 localtileserver-0.10.4 lxml-5.3.0 morecantile-5.4.2 netcdf4-1.7.1.post2 numexpr-2.10.1 numpy-2.1.2 owslib-0.31.0 psutil-6.0.0 psygnal-0.11.1 py3dep-0.18.0 pycares-4.4.0 pygeoogc-0.18.0 pygeoutils-0.18.0 pynhd-0.18.0 pystac-1.11.0 pystac-client-0.8.3 rasterio-1.4.1 requests-cache-1.2.1 rio-cogeo-5.3.6 rio-tiler-6.7.0 rioxarray-0.17.0 server-thread-0.2.0 simpervisor-1.0.0 ujson-5.10.0 url-normalize-1.4.3 whitebox-2.3.5 whiteboxgui-2.3.0 xarray-2024.9.0

# %%
# !gdalinfo --version
# Out:
# /bin/bash: line 1: gdalinfo: command not found

# %%
from __future__ import annotations
import os

import ee
import google.auth

import folium
from serving import data
import json
from branca.element import Figure
from folium import plugins
import sys
from serving.data import get_input_image
from importlib import reload

# %%
current_dir = os.getcwd()
sys.path.append(current_dir+'/serving')

# %%
# Google cloud parameters
project = "supple-nature-370421"  # @param {type:"string"}
bucket = "vgnn"  # @param {type:"string"}
location = "us-west2-a"  # @param {type:"string"}

# Quick input validations.
assert project, "⚠️ Please provide a Google Cloud project ID"
assert bucket, "⚠️ Please provide a Cloud Storage bucket name"
assert not bucket.startswith(
    "gs://"
), f"⚠️ Please remove the gs:// prefix from the bucket name: {bucket}"
assert location, "⚠️ Please provide a Google Cloud location"

# Set GOOGLE_CLOUD_PROJECT for google.auth.default().
os.environ["GOOGLE_CLOUD_PROJECT"] = project

# Set the gcloud project for other gcloud commands.
# !gcloud config set project {project}

# Initialise goofle earth engine
credentials, _ = google.auth.default()
ee.Initialize(
    credentials.with_quota_project(None),
    project=project,
    opt_url="https://earthengine-highvolume.googleapis.com",
)
# Out:
# Updated property [core/project].

# %%
#CONSTANTS
YEAR_START=2017
YEAR_END=2023

SEASON_START=5
SEASON_END=10

CROP=1 #Corn

# True vision params
vis_params = {
    "min": 0,
    "max": 3000,
    "bands": ["B4", "B3", "B2"],}

# %%
# reload(data)

# Show sample filter

start_year = 2017
start_month = 4
end_month = 7
crop_type = 1 # Corn
county = "Story"

county_geom = (
    ee.FeatureCollection("TIGER/2018/Counties")
    .filter(ee.Filter.eq("NAME", county))
).geometry()

coords = county_geom.centroid().coordinates().getInfo()

s2_img_start = get_input_image(county, crop_type, start_year, start_month).clip(county_geom)
s2_img_end = get_input_image(county, crop_type, start_year, end_month).clip(county_geom)

# %%
# Create the map
m1 = folium.Map(coords[::-1])

# Add the CDL layer
layer_left = folium.TileLayer(
    tiles=s2_img_start.getMapId(vis_params)["tile_fetcher"].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    name='Cropland Data Layer',
    overlay=True,
    control=True
)

layer_right = folium.TileLayer(
    tiles=s2_img_end.getMapId(vis_params)["tile_fetcher"].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    name='Cropland Data Layer',
    overlay=True,
    control=True
)

sbs = plugins.SideBySideLayers(layer_left=layer_left, layer_right=layer_right)

layer_left.add_to(m1)
layer_right.add_to(m1)
sbs.add_to(m1)    

# Display the map
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43922b09d7adbbf3b713c35cf432b561 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43922b09d7adbbf3b713c35cf432b561&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43922b09d7adbbf3b713c35cf432b561 = L.map(
#                 &quot;map_43922b09d7adbbf3b713c35cf432b561&quot;,
#                 {
#                     center: [42.036163742098324, -93.46504560761413],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f1555af8142d575f5f323b741138c13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7f1555af8142d575f5f323b741138c13.addTo(map_43922b09d7adbbf3b713c35cf432b561);
#
#
#             var tile_layer_a8f503749f8c0b3bf1a2df3023458899 = L.tileLayer(
#                 &quot;https://earthengine-highvolume.googleapis.com/v1/projects/supple-nature-370421/maps/8d803a9f799f10005e75decfb99df78f-0b7743dec525d387af59ff9f184e7858/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a8f503749f8c0b3bf1a2df3023458899.addTo(map_43922b09d7adbbf3b713c35cf432b561);
#
#
#             var tile_layer_73867b869bd781028c2c17e8e692fb16 = L.tileLayer(
#                 &quot;https://earthengine-highvolume.googleapis.com/v1/projects/supple-nature-370421/maps/d8d0b17d64f82568f7b90c160c3f1d67-7282634a0642d2b5dc69a75801291da6/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_73867b869bd781028c2c17e8e692fb16.addTo(map_43922b09d7adbbf3b713c35cf432b561);
#
#
#             var side_by_side_layers_f359e18602a277b353608c713ae3538e = L.control.sideBySide(
#                 tile_layer_a8f503749f8c0b3bf1a2df3023458899, tile_layer_73867b869bd781028c2c17e8e692fb16
#             ).addTo(map_43922b09d7adbbf3b713c35cf432b561);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
"""
Changes in crops can be observable in the satellite images. Once can hope that the colour saturation and temporal change would hold predictive power
"""
# Out:
# '\nChanges in crops can be observable in the satellite images. Once can hope that the colour saturation and temporal change would hold predictive power\n'

# %%
img_name = f"{county}_{start_year}_{start_month}-{start_month+1}"
img_task = ee.batch.Export.image.toCloudStorage(
    image=s2_img_start,
    description=img_name,
    bucket=bucket,
    fileNamePrefix=f"images/{img_name}",
    scale=30,
    region=county_geom,
)
img_task.start()

# %%
json.dumps(s2_img_start.getInfo(), indent=2)
# Out:
# '{\n  "type": "Image",\n  "bands": [\n    {\n      "id": "B1",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n      "crs_transform": [\n        1,\n        0,\n        0,\n        0,\n        1,\n        0\n      ]\n    },\n    {\n      "id": "B2",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n      "crs_transform": [\n        1,\n        0,\n        0,\n        0,\n        1,\n        0\n      ]\n    },\n    {\n      "id": "B3",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n      "crs_transform": [\n        1,\n        0,\n        0,\n        0,\n        1,\n        0\n      ]\n    },\n    {\n      "id": "B4",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n      "crs_transform": [\n        1,\n        0,\n        0,\n        0,\n        1,\n        0\n      ]\n    },\n    {\n      "id": "B5",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n      "crs_transform": [\n        1,\n        0,\n        0,\n        0,\n        1,\n        0\n      ]\n    },\n    {\n      "id": "B6",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n      "crs_transform": [\n        1,\n        0,\n        0,\n        0,\n        1,\n        0\n      ]\n    },\n    {\n      "id": "B7",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n      "crs_transform": [\n        1,\n        0,\n        0,\n        0,\n        1,\n        0\n      ]\n    },\n    {\n      "id": "B8",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n      "crs_transform": [\n        1,\n        0,\n        0,\n        0,\n        1,\n        0\n      ]\n    },\n    {\n      "id": "B8A",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n      "crs_transform": [\n        1,\n        0,\n        0,\n        0,\n        1,\n        0\n      ]\n    },\n    {\n      "id": "B9",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n      "crs_transform": [\n        1,\n        0,\n        0,\n        0,\n        1,\n        0\n      ]\n    },\n    {\n      "id": "B10",\n      "data_type": {\n        "type": "PixelType",\n        "precision": "float"\n      },\n      "dimensions": [\n        3,\n        2\n      ],\n      "origin": [\n        -95,\n        41\n      ],\n      "crs": "EPSG:4326",\n     ...
